# %%
import numpy as np

print(np.__version__)
# Out:
# 2.4.2
# 2.3.3

# %%
arr = np.array([1,2,3,4,5])
print(arr)
print(arr.ndim)
print(type(arr))
print(arr.dtype)
# Out:
# [1 2 3 4 5]
# 1
# <class 'numpy.ndarray'>
# int64
